# %%
using NotebookHelper
NotebookHelper.setup("34d189b6-397b-401f-b83e-89c1c8763f23")
# Out:
# Notebook:           /home/arndt/tmp/julia-proj-example/Folder1/Notebook2.ipynb
# Current directory:  /home/arndt/tmp/julia-proj-example/Folder1
# Hostname:           elcattivo.molgen.mpg.de
# PID:                107527 (in Jupyter)
# Username:           arndt
# Julia version:      1.9.2
# Julia environment:  /home/arndt/tmp/julia-proj-example/Project.toml
# Date:               2023-08-03T15:25:02.667

# %%
using PyPlot

# %%
fig = figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.scatter(rand(100), rand(100), 50)

NotebookHelper.annotate(ax)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
